# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import random

# %%
mnist=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)= mnist.load_data()

x_train=x_train/255
x_test=x_test/255

# %%
print('x train shape : ',x_train.shape)
print('x test shape : ',x_test.shape)
print('y train shape : ',y_train.shape)
print('y test shape : ',y_test.shape)
# Out:
# x train shape :  (60000, 28, 28)
# x test shape :  (10000, 28, 28)
# y train shape :  (60000,)
# y test shape :  (10000,)

# %%
model=Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation = 'relu'),
    keras.layers.Dense(10,activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 128)               100480
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=30)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.6448 - accuracy: 0.8374 - val_loss: 0.3590 - val_accuracy: 0.9047
# Epoch 2/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3362 - accuracy: 0.9063 - val_loss: 0.2950 - val_accuracy: 0.9190
# Epoch 3/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2902 - accuracy: 0.9188 - val_loss: 0.2625 - val_accuracy: 0.9266
# Epoch 4/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2615 - accuracy: 0.9271 - val_loss: 0.2421 - val_accuracy: 0.9326
# Epoch 5/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2391 - accuracy: 0.9332 - val_loss: 0.2233 - val_accuracy: 0.9390
# Epoch 6/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2207 - accuracy: 0.9394 - val_loss: 0.2107 - val_accuracy: 0.9406
# Epoch 7/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2049 - accuracy: 0.9431 - val_loss: 0.1947 - val_accuracy: 0.9445
# Epoch 8/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1910 - accuracy: 0.9476 - val_loss: 0.1842 - val_accuracy: 0.9476
# Epoch 9/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1790 - accuracy: 0.9504 - val_loss: 0.1741 - val_accuracy: 0.9509
# Epoch 10/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1683 - accuracy: 0.9534 - val_loss: 0.1644 - val_accuracy: 0.9526
# Epoch 11/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1586 - accuracy: 0.9561 - val_loss: 0.1573 - val_accuracy: 0.9554
# Epoch 12/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1502 - accuracy: 0.9580 - val_loss: 0.1485 - val_accuracy: 0.9560
# Epoch 13/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1427 - accuracy: 0.9604 - val_loss: 0.1463 - val_accuracy: 0.9574
# Epoch 14/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1359 - accuracy: 0.9621 - val_loss: 0.1391 - val_accuracy: 0.9591
# Epoch 15/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1300 - accuracy: 0.9638 - val_loss: 0.1319 - val_accuracy: 0.9616
# Epoch 16/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1242 - accuracy: 0.9652 - val_loss: 0.1284 - val_accuracy: 0.9616
# Epoch 17/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1192 - accuracy: 0.9667 - val_loss: 0.1235 - val_accuracy: 0.9633
# Epoch 18/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1144 - accuracy: 0.9683 - val_loss: 0.1210 - val_accuracy: 0.9645
# Epoch 19/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1100 - accuracy: 0.9693 - val_loss: 0.1181 - val_accuracy: 0.9651
# Epoch 20/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1061 - accuracy: 0.9711 - val_loss: 0.1140 - val_accuracy: 0.9670
# Epoch 21/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1023 - accuracy: 0.9721 - val_loss: 0.1114 - val_accuracy: 0.9667
# Epoch 22/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0989 - accuracy: 0.9726 - val_loss: 0.1089 - val_accuracy: 0.9680
# Epoch 23/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0955 - accuracy: 0.9741 - val_loss: 0.1068 - val_accuracy: 0.9682
# Epoch 24/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0924 - accuracy: 0.9746 - val_loss: 0.1047 - val_accuracy: 0.9692
# Epoch 25/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0896 - accuracy: 0.9753 - val_loss: 0.1028 - val_accuracy: 0.9697
# Epoch 26/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0870 - accuracy: 0.9761 - val_loss: 0.1010 - val_accuracy: 0.9699
# Epoch 27/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0842 - accuracy: 0.9767 - val_loss: 0.0981 - val_accuracy: 0.9715
# Epoch 28/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0819 - accuracy: 0.9776 - val_loss: 0.0965 - val_accuracy: 0.9711
# Epoch 29/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0796 - accuracy: 0.9782 - val_loss: 0.0951 - val_accuracy: 0.9720
# Epoch 30/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0775 - accuracy: 0.9785 - val_loss: 0.0942 - val_accuracy: 0.9715

# %%
test_loss, test_accuracy=model.evaluate(x_test,y_test)
print('loss=%.3f'%test_loss)
print('accuracy=%.3f'%test_accuracy)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0942 - accuracy: 0.9715
# loss=0.094
# accuracy=0.971

# %%
import numpy as np
n=random.randint(0,9999)
plt.imshow(x_test[n])
plt.show()
predicted_value=model.predict(x_test)

plt.show()
print('Predicted value:',np.argmax(predicted_value[n]))
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Predicted value: 6

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.show()

# %%
fashion_mnist=tf.keras.datasets.fashion_mnist.load_data()

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist

assert x_train.shape == (60000, 28, 28)
assert x_test.shape == (10000, 28, 28)
assert y_train.shape == (60000,)
assert y_test.shape == (10000,)

# %%
plt.imshow(x_train[22])
print(y_train[22])
# Out:
# 4
